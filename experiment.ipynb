# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores  import FAISS
from dotenv import load_dotenv

load_dotenv()
# Out:
# WARNING:tensorflow:From c:\Users\Crashlar\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# True

# %%
path = "C:/Users/Crashlar/Desktop/Tackling the Poor Assumptions of Naive Bayes Text Classifiers.pdf"
loader = PyPDFLoader(path)

docs = loader.load()

# %%
for document in docs:
    # print(document.page_content)
    pass

# %%
# splitter

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size = 200 , 
    chunk_overlap = 0 , 
    separators=["/n" , "/n/n" , "."]
)


chunks = splitter.split_documents(docs)

# %%
chunks[0].metadata
# Out:
# {'producer': 'pdfTeX-0.13d',
#  'creator': 'TeX',
#  'creationdate': 'D:20030707071200',
#  'source': 'C:/Users/Crashlar/Desktop/Tackling the Poor Assumptions of Naive Bayes Text Classifiers.pdf',
#  'total_pages': 8,
#  'page': 0,
#  'page_label': '1'}

# %%
chunks[100].page_content
# Out:
# '. Then, each time\na test document has an occurrence of “San Francisco,”\nMultinomial Naive Bayes will double count—it will\nadd in the weight for “San” and the weight for “Fran-\ncisco'

# %%
len(chunks)
# Out:
# 228

# %%
# embedding

# %%
from langchain_huggingface import HuggingFaceEmbeddings

# Initialize the embedding model
embedding_model = HuggingFaceEmbeddings(
    model_name="Qwen/Qwen3-Embedding-0.6B"
    )

vector_store = FAISS.from_documents(chunks, embedding_model)

# %%
vector_store.index_to_docstore_id
# Out:
# {0: '9b766f16-eeab-4820-bea6-ecc72d89e017',
#  1: '20519118-0e75-4aad-a670-fb16ff9981e8',
#  2: '3e041922-aa70-4a7e-bc05-5fcd583af4da',
#  3: '0d4c428d-b94b-4d16-a449-59039ffa55dc',
#  4: '448bc694-7079-4821-8714-2197beb9ad2c',
#  5: 'bcae521f-a99b-4c89-88f6-d5c842d5ac2c',
#  6: 'aae81a3a-f826-44d2-8176-3729415ce765',
#  7: '2e7995ea-a72d-43d5-9f93-1e6cde69992d',
#  8: 'a49578ca-68f9-42ea-a093-2bd7abc9a136',
#  9: '5dde3ec0-4a78-4ab1-8d4a-145fd13a5868',
#  10: '38c2ce20-c6f7-4b33-a20b-13f2fd05e488',
#  11: '0b146af2-a239-4da0-8c6f-63062cba2262',
#  12: '8f9ae874-b859-4e49-8914-ea86467e0fca',
#  13: '795f3f7d-2184-413a-a16d-ff43b556a20b',
#  14: 'c3b522f2-c854-4f6b-8f18-5e616ab9766e',
#  15: 'de56e2ff-ad81-4d2a-b797-27698594479d',
#  16: 'ad034ca1-87bb-4ecf-8489-b73e00ed8b38',
#  17: '53c98f63-1f5e-4a02-8208-c52315f36ad8',
#  18: 'fb741e9a-d7cb-469b-9386-ee7fd6cc3889',
#  19: 'eefc8638-33c5-4b29-82cc-6b3cb9fa21a6',
#  20: '19fdc27b-a16c-4239-9c46-02e0d34e0175',
# ...

# %%
vector_store.get_by_ids(['830e1d88-eb0d-4c89-b607-4b37024e302d'])
vector_store.get_by_ids(['9b766f16-eeab-4820-bea6-ecc72d89e017'])
# Out:
# [Document(id='9b766f16-eeab-4820-bea6-ecc72d89e017', metadata={'producer': 'pdfTeX-0.13d', 'creator': 'TeX', 'creationdate': 'D:20030707071200', 'source': 'C:/Users/Crashlar/Desktop/Tackling the Poor Assumptions of Naive Bayes Text Classifiers.pdf', 'total_pages': 8, 'page': 0, 'page_label': '1'}, page_content='Tackling the Poor Assumptions of Naive Bayes Text Classiﬁers\nJason D. M. Rennie jrennie@mit.edu\nLawrence Shih kai@mit.edu\nJaime Teevan teevan@mit.edu\nDavid R. Karger karger@mit')]

# %%
retriever = vector_store.as_retriever(search_type="similarity", search_kwargs={"k": 4})

# %%
retriever
# Out:
# VectorStoreRetriever(tags=['FAISS', 'HuggingFaceEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x00000129D647D940>, search_kwargs={'k': 4})

# %%
retriever.invoke('What is Naive Bayes')
# Out:
# [Document(id='3630a119-d28d-4638-afe2-335819041f57', metadata={'producer': 'pdfTeX-0.13d', 'creator': 'TeX', 'creationdate': 'D:20030707071200', 'source': 'C:/Users/Crashlar/Desktop/Tackling the Poor Assumptions of Naive Bayes Text Classifiers.pdf', 'total_pages': 8, 'page': 7, 'page_label': '8'}, page_content='Naive Bayes classiﬁer to text data. A series of trans-\nforms from the information retrieval community, Steps\n1-3 in Table 4, improves the performance of Naive\nBayes text classiﬁcation'),
#  Document(id='5dde3ec0-4a78-4ab1-8d4a-145fd13a5868', metadata={'producer': 'pdfTeX-0.13d', 'creator': 'TeX', 'creationdate': 'D:20030707071200', 'source': 'C:/Users/Crashlar/Desktop/Tackling the Poor Assumptions of Naive Bayes Text Classifiers.pdf', 'total_pages': 8, 'page': 0, 'page_label': '1'}, page_content='. We also better\nmatch the distribution of text with the distribution\nassumed by Naive Bayes'),
# ...
